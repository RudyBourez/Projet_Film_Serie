# %%
import pandas as pd

# %%
data = pd.read_csv("films.csv", encoding="utf-8")

# %%
data_sorted = data.loc[data["type"].str.contains("Drama")]
data_sorted
# Out:
#                                 title  \
# 0                          Les Évadés
# 5       Il faut sauver le soldat Ryan
# 9                    La vie est belle
# 13   Vol au-dessus d'un nid de coucou
# 17                       Paris, Texas
# ..                                ...
# 221                        Casablanca
# 226                          Whiplash
# 228                American History X
# 241                        Fight Club
# 242                      Forrest Gump
#
#                                       original_title  score   type  date  \
# 0           Original title: The Shawshank Redemption    9.3  Drama  1994
# 5                Original title: Saving Private Ryan    8.6  Drama  1998
# 9              Original title: It's a Wonderful Life    8.6  Drama  1946
# 13   Original title: One Flew Over the Cuckoo's Nest    8.7  Drama  1975
# 17                                               NaN    8.1  Drama  1984
# ...

# %%
data["actors"].unique()
# Out:
# array(['Tim Robbins,Morgan Freeman,Bob Gunton,William Sadler,Clancy Brown,Gil Bellows,Mark Rolston,James Whitmore,Jeffrey DeMunn,Larry Brandenburg,Neil Giuntoli,Brian Libby,David Proval,Joseph Ragno,Jude Ciccolella,Paul McCrane,Renee Blaine,Scott Mann',
#        'Tom Hanks,Michael Clarke Duncan,David Morse,Bonnie Hunt,James Cromwell,Michael Jeter,Graham Greene,Doug Hutchison,Sam Rockwell,Barry Pepper,Jeffrey DeMunn,Patricia Clarkson,Harry Dean Stanton,Dabbs Greer,Eve Brent,William Sadler,Mack Miles,Rai Tasco',
#        'Matthew McConaughey,Anne Hathaway,Jessica Chastain,Mackenzie Foy,Ellen Burstyn,John Lithgow,Timothée Chalamet,David Oyelowo,Collette Wolfe,Francis X. McCarthy,Bill Irwin,Andrew Borba,Wes Bentley,William Devane,Michael Caine,David Gyasi,Josh Stewart,Casey Affleck',
# ...

# %%
liste = []
for i in range (len(data["actors"])):
    liste += data["actors"][i].split(',')
# Out:
# ['Tim Robbins',
#  'Morgan Freeman',
#  'Bob Gunton',
#  'William Sadler',
#  'Clancy Brown',
#  'Gil Bellows',
#  'Mark Rolston',
#  'James Whitmore',
#  'Jeffrey DeMunn',
#  'Larry Brandenburg',
#  'Neil Giuntoli',
#  'Brian Libby',
#  'David Proval',
#  'Joseph Ragno',
#  'Jude Ciccolella',
#  'Paul McCrane',
#  'Renee Blaine',
#  'Scott Mann',
#  'Tom Hanks',
#  'Michael Clarke Duncan',
#  'David Morse',
#  'Bonnie Hunt',
#  'James Cromwell',
#  'Michael Jeter',
#  'Graham Greene',
#  'Doug Hutchison',
#  'Sam Rockwell',
#  'Barry Pepper',
#  'Jeffrey DeMunn',
#  'Patricia Clarkson',
#  'Harry Dean Stanton',
#  'Dabbs Greer',
#  'Eve Brent',
#  'William Sadler',
#  'Mack Miles',
#  'Rai Tasco',
#  'Matthew McConaughey',
#  'Anne Hathaway',
#  'Jessica Chastain',
#  'Mackenzie Foy',
#  'Ellen Burstyn',
#  'John Lithgow',
#  'Timothée Chalamet',
#  'David Oyelowo',
#  'Collette Wolfe',
#  'Francis X. McCarthy',
#  'Bill Irwin',
#  'Andrew Borba',
#  'Wes Bentley',
# ...

# %%
[i.replace(",", " ") for i in range(len(data["actors"])) for i in data["actors"][i].split()]
# Out:
# ['Tim',
#  'Robbins,Morgan',
#  'Freeman,Bob',
#  'Gunton,William',
#  'Sadler,Clancy',
#  'Brown,Gil',
#  'Bellows,Mark',
#  'Rolston,James',
#  'Whitmore,Jeffrey',
#  'DeMunn,Larry',
#  'Brandenburg,Neil',
#  'Giuntoli,Brian',
#  'Libby,David',
#  'Proval,Joseph',
#  'Ragno,Jude',
#  'Ciccolella,Paul',
#  'McCrane,Renee',
#  'Blaine,Scott',
#  'Mann',
#  'Tom',
#  'Hanks,Michael',
#  'Clarke',
#  'Duncan,David',
#  'Morse,Bonnie',
#  'Hunt,James',
#  'Cromwell,Michael',
#  'Jeter,Graham',
#  'Greene,Doug',
#  'Hutchison,Sam',
#  'Rockwell,Barry',
#  'Pepper,Jeffrey',
#  'DeMunn,Patricia',
#  'Clarkson,Harry',
#  'Dean',
#  'Stanton,Dabbs',
#  'Greer,Eve',
#  'Brent,William',
#  'Sadler,Mack',
#  'Miles,Rai',
#  'Tasco',
#  'Matthew',
#  'McConaughey,Anne',
#  'Hathaway,Jessica',
#  'Chastain,Mackenzie',
#  'Foy,Ellen',
#  'Burstyn,John',
#  'Lithgow,Timothée',
#  'Chalamet,David',
#  'Oyelowo,Collette',
#  'Wolfe,Francis',
#  'X.',
#  'McCarthy,Bill',
#  'Irwin,Andrew',
# ...
